# %% [markdown]
# # 一级标题
# ## 二级标题
# ### 三级标题
# #### 四级标题
# 最多能到六级
#
#
#
# 标题
# ====
# 标题
# ----
# hello
# 我是宋
#
# hello<br>world
# **hello** world
# __hello__ world
# **impor**tant
#
# I am a ***Chinese*** student.
#
# I am a ___Chinese___student.
# >引用内容
# >
# >引用内容
# >### 三级标题引用内容
# >>#### 分层的四级级标题引用内容
# >>>- 无序列表引用内容
# >>>- ***其他***内容__使用__效**果**。
#
# 1. 第一行
# 2. 第二行
# 3. 第三行
# * 第一行
# * 第二行
# * 第三行
# ### 接下来错误示范
# 1.第一行
# 2.第二行
# 3.第三行
# * 第一行
# - 第二行
# + 第三行
#
#
# - 第一行
#     >hello world
# - 第一行
#     你好世界！
#     - 第二行
# - 第一行
#     - 第二行

# %% [markdown]
# `code` is my love!
# _____________________________________
# ``print("hello world")``
# *********************
# ``Use `code` in your Markdown file.``
# -----------------------------------------
#     def fun():
#         print("hello world")
#     fun()
# 这是一个markdown官网链接[markdown](https://markdown.com.cn/basic-syntax/links.html)
#
#
#
#
# I love supporting the **[EFF](https://eff.org)**.
# I love supporting the *[EFF](https://eff.org)*.
# This is the _[Markdown Guide](https://www.markdownguide.org)_.
# This is the __[Markdown Guide](https://www.markdownguide.org)__.
# See the section on [`code`](#code).
#
#
# [![海贼王]("One Piece")](https://cn.bing.com/images/search?view=detailV2&ccid=2g9l9Utj&id=A9863A6D505C9A888B95D673197BD6DBCDC286CC&thid=OIP.2g9l9UtjmDo-2kZ9FPGQKgHaFM&mediaurl=https%3a%2f%2fpic1.zhimg.com%2fv2-7d67ce1351f17f44021f914e9260634d_r.jpg%3fsource%3d1940ef5c&exph=1348&expw=1920&q=%e6%b5%b7%e8%b4%bc%e7%8e%8b%e5%9b%be%e7%89%87&simid=608043868091728525&FORM=IRPRST&ck=DA4A4FC408692FB9D2F97E64E4ED521E&selectedIndex=13&itb=0 )
#
# [![沙漠中的岩石图片](/assets/img/shiprock.jpg "Shiprock")](https://markdown.com.cn)

# %% [markdown]
# \# 世界
# # 世界
# AT&T
# 4 < 5
#
# |姓名|年龄|性别|
# |:---|:---:|---:|
# |**小明**|__20__|男|
# |\|小王|18  |女|
#
# ~~~json
# {
#   def fun(n):
#     for i in range(n):
#       print(i)
#   n = int(input())
#   fun(n)
# }
# ~~~
#
# 你的名字[^1]和我的名字[^2]是一样的[^cool]
#
# [^1]: xiaomming
# [^2]: xiaowang
# [^cool]: shuai
#
# ~~战争~~， 愿世界和平。
# - [x] 背单词
#
# 😂
#
# `http://www.example.com`
